# %% [markdown]
# # Notebook 04: Risk Analysis
#
# **Goal**: Identify servers projected to breach capacity thresholds in 2025.
#
# **Steps**:
# 1. Load Model & Data.
# 2. Generate Predictions for 2025.
# 3. Flag breaches (>80% CPU).
# 4. Generate Report.

# %%
import sys
import os
from pathlib import Path

# Add src to path
project_root = Path(os.getcwd()).parent
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

from src.risk_analysis import RiskAnalyzer
import pandas as pd

# %%
analyzer = RiskAnalyzer(
    data_path=str(project_root / "data" / "processed" / "processed_metrics.parquet"),
    model_path=str(project_root / "models"),
    output_path=str(project_root / "reports")
)

risky_servers = analyzer.run()

# %% [markdown]
# ## Risk Summary

# %%
print(f"Total Servers at Risk: {len(risky_servers)}")
risky_servers.head(10)
# Out:
# Total Servers at Risk: 0
# Empty DataFrame
# Columns: [server_id, max_predicted_cpu, mean_predicted_cpu, breach_days]
# Index: []
