# %% [markdown]
# # Notebook 05: Visualization & Reporting
#
# **Goal**: Visualize model performance and generate reporting artifacts.
#
# **Steps**:
# 1. Load Data & Model.
# 2. Plot Forecast vs Actuals for sample servers.
# 3. Visualize Feature Importance.

# %%
import sys
import os
from pathlib import Path

# Add src to path
project_root = Path(os.getcwd()).parent
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

from src.visualization import Dashboard
import matplotlib.pyplot as plt

# %%
dashboard = Dashboard(
    data_path=str(project_root / "data" / "processed" / "processed_metrics.parquet"),
    model_path=str(project_root / "models"),
    output_path=str(project_root / "reports" / "plots")
)

dashboard.run()

# %% [markdown]
# ### Generated plots saved to `reports/plots/`.
